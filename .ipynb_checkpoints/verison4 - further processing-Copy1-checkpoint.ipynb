# %% [markdown]
# ## Setup

# %%
import pandas as pd
patient_history=pd.read_csv('./vaccine reaction/2021VAERSDATA.CSV', sep=',', encoding='ISO-8859-1')
patient_sympt=pd.read_csv('./vaccine reaction/2021VAERSSYMPTOMS.CSV', sep=',',encoding='ISO-8859-1')
patient_vac=pd.read_csv('./vaccine reaction/2021VAERSVAX.CSV', sep=',',encoding='ISO-8859-1')
# Out:
# C:\Users\zelon\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3155: DtypeWarning: Columns (7,12,23) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
pd.set_option("display.max_rows", 1000)

# %%
patient_history.head(2)
# Out:
#    VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0    916600  01/01/2021    TX     33.0     33.0      NaN   F      NaN
# 1    916601  01/01/2021    CA     73.0     73.0      NaN   F      NaN
#
#                                         SYMPTOM_TEXT DIED  ...  \
# 0  Right side of epiglottis swelled up and hinder...  NaN  ...
# 1  Approximately 30 min post vaccination administ...  NaN  ...
#
#                                              CUR_ILL  \
# 0                                               None
# 1  Patient residing at nursing facility. See pati...
#
#                                              HISTORY PRIOR_VAX SPLTTYPE  \
# 0                                               None       NaN      NaN
# 1  Patient residing at nursing facility. See pati...       NaN      NaN
#
#    FORM_VERS TODAYS_DATE BIRTH_DEFECT OFC_VISIT ER_ED_VISIT          ALLERGIES
# 0          2  01/01/2021          NaN         Y         NaN  Pcn and bee venom
# 1          2  01/01/2021          NaN         Y         NaN            "Dairy"
#
# [2 rows x 35 columns]

# %% [markdown]
# ## Data preprocessing

# %%
 # get the needed columns from patient history file
patient_history=patient_history.loc[: , ['VAERS_ID','AGE_YRS','SEX','CUR_ILL','HISTORY','ALLERGIES']]
 # get the needed columns from patient vaccine file
patient_vac=patient_vac.loc[:,['VAERS_ID','VAX_NAME']]
 # commbining reactions per patient 
patient_sympt['SYMPTOMS']= patient_sympt['SYMPTOM1'].fillna('')+','+ patient_sympt['SYMPTOM2'].fillna('')+','+ patient_sympt['SYMPTOM3'].fillna('')+','+ patient_sympt['SYMPTOM4'].fillna('')+','+ patient_sympt['SYMPTOM5'].fillna('')
patient_sympt=patient_sympt.groupby(by='VAERS_ID')['SYMPTOMS'].agg(lambda x: ','.join(x)).reset_index()

# %%
 # mergeing all extracted info above to a single dataframe 
#df=pd.merge(patient_history, patient_vac, left_on='VAERS_ID', right_on='VAERS_ID')
df=patient_history.merge( patient_vac , on='VAERS_ID')

# %%
df=pd.merge(df, patient_sympt,  left_on='VAERS_ID', right_on='VAERS_ID')
df=df.fillna(value="")
# prepare y values step1 
# make symptom columns into a list 
df['SYMPTOMS']=df['SYMPTOMS'].apply(lambda x : x.split(","))
# and than remove any empty values in the list. 
df['SYMPTOMS']=df['SYMPTOMS'].apply(lambda x : [i for i in x if i])
df=df.drop_duplicates(['VAERS_ID'])
df[df['VAERS_ID']==1015465]
# Out:
#        VAERS_ID AGE_YRS SEX  \
# 22431   1015465    75.0   F
#
#                                                  CUR_ILL  \
# 22431  U07.1 2019-nCoV acute respiratory disease (Pri...
#
#                                                  HISTORY  \
# 22431  U07.1 2019-nCoV acute respiratory disease (Pri...
#
#                                                ALLERGIES  \
# 22431  Iodinated Contrast- Oral and IV Dye, Penicilli...
#
#                           VAX_NAME  \
# 22431  COVID19 (COVID19 (MODERNA))
#
#                                                 SYMPTOMS
# 22431  [Heart rate abnormal, Pulse absent, Respirator...

# %%
def convertAge(string_age):
    if string_age =="" :
        return "unknown_age"
    if float(string_age) <= 60 :
        return 'under_60'
    return "over_60"

def changeVaxName(vax_name):
    if 'MODERNA'in vax_name:
        return 'MODERNA'
    if 'PFIZER' in vax_name:
        return 'PFIZER'
    
    return 'JANSSEN'

# %%
# remove none coivd related vaccine samples 
df=df[df['VAX_NAME'].str.contains('|'.join(['MODERNA','JANSSEN','PFIZER-BIONTECH'])) & df['VAX_NAME'].isna()==False]
# put age in bucket under 60 or over
df['AGE_CAT']=df['AGE_YRS'].apply(lambda x : convertAge(x) )
# simmplify vaccine names 
df['VAX_NAME']=df['VAX_NAME'].apply(lambda x : changeVaxName(x))
df
# Out:
#        VAERS_ID AGE_YRS SEX  \
# 0        916600    33.0   F
# 1        916601    73.0   F
# 2        916602    23.0   F
# 3        916603    58.0   F
# 4        916604    47.0   F
# ...         ...     ...  ..
# 34625   1113917    88.0   F
# 34626   1113920    83.0   F
# 34627   1113963    59.0   F
# 34628   1115045    57.0   M
# 34629   1115348           F
#
#                                                  CUR_ILL  \
# 0                                                   None
# 1      Patient residing at nursing facility. See pati...
# 2                                                   None
# 3                                       kidney infection
# 4                                                     Na
# ...                                                  ...
# 34625
# 34626
# 34627
# 34628
# 34629
#
#                                                  HISTORY  \
# 0                                                   None
# 1      Patient residing at nursing facility. See pati...
# 2                                                   None
# 3      diverticulitis, mitral valve prolapse, osteoar...
# 4
# ...                                                  ...
# 34625  Medical History/Concurrent Conditions: Aortic ...
# 34626  Medical History/Concurrent Conditions: Atrial ...
# 34627  Medical History/Concurrent Conditions: Type II...
# 34628  Medical History/Concurrent Conditions: No adve...
# 34629  Comments: List of non-encoded Patient Relevant...
#
#                                                ALLERGIES VAX_NAME  \
# 0                                      Pcn and bee venom  MODERNA
# 1                                                "Dairy"  MODERNA
# 2                                              Shellfish   PFIZER
# 3      Diclofenac, novacaine, lidocaine, pickles, tom...  MODERNA
# 4                                                     Na  MODERNA
# ...                                                  ...      ...
# 34625                                                     MODERNA
# 34626                                                      PFIZER
# 34627                                                      PFIZER
# 34628                                                     MODERNA
# 34629                                                     MODERNA
#
#                                                 SYMPTOMS      AGE_CAT
# 0                              [Dysphagia, Epiglottitis]     under_60
# 1                                    [Anxiety, Dyspnoea]      over_60
# 2      [Chest discomfort, Dysphagia, Pain in extremit...     under_60
# 3               [Dizziness, Fatigue, Mobility decreased]     under_60
# 4      [Injection site erythema, Injection site pruri...     under_60
# ...                                                  ...          ...
# 34625                   [Dysphagia, Hernia, Obstruction]      over_60
# 34626  [Arrhythmia, Asymptomatic COVID-19, Chills, Co...      over_60
# 34627  [Haemophagocytic lymphohistiocytosis, SARS-CoV...     under_60
# 34628                                            [Death]     under_60
# 34629                                            [Death]  unknown_age
#
# [34121 rows x 9 columns]

# %%
# Create a list of remove words
remove_word_list = ['none', 'na']

def remove_words(strings):
    for words in remove_word_list:
        strings = strings.replace(words, '')
    return strings

# %%
# make the health_condition text lower case 
df['CUR_ILL']=df['CUR_ILL'].str.lower()
df['HISTORY']=df['HISTORY'].str.lower()
df['ALLERGIES']=df['ALLERGIES'].str.lower()
# remove list of words from columns

df['CUR_ILL']=df['CUR_ILL'].apply(lambda x : remove_words(x)  )
df['HISTORY']=df['HISTORY'].apply(lambda x : remove_words(x)  )
df['ALLERGIES']=df['ALLERGIES'].apply(lambda x : remove_words(x)  )

# %%
df
# Out:
#        VAERS_ID AGE_YRS SEX  \
# 0        916600    33.0   F
# 1        916601    73.0   F
# 2        916602    23.0   F
# 3        916603    58.0   F
# 4        916604    47.0   F
# ...         ...     ...  ..
# 34625   1113917    88.0   F
# 34626   1113920    83.0   F
# 34627   1113963    59.0   F
# 34628   1115045    57.0   M
# 34629   1115348           F
#
#                                                  CUR_ILL  \
# 0
# 1      patient residing at nursing facility. see pati...
# 2
# 3                                       kidney infection
# 4
# ...                                                  ...
# 34625
# 34626
# 34627
# 34628
# 34629
#
#                                                  HISTORY  \
# 0
# 1      patient residing at nursing facility. see pati...
# 2
# 3      diverticulitis, mitral valve prolapse, osteoar...
# 4
# ...                                                  ...
# 34625  medical history/concurrent conditions: aortic ...
# 34626  medical history/concurrent conditions: atrial ...
# 34627  medical history/concurrent conditions: type ii...
# 34628  medical history/concurrent conditions: no adve...
# 34629  comments: list of non-encoded patient relevant...
#
#                                                ALLERGIES VAX_NAME  \
# 0                                      pcn and bee venom  MODERNA
# 1                                                "dairy"  MODERNA
# 2                                              shellfish   PFIZER
# 3      diclofec, novacaine, lidocaine, pickles, tomat...  MODERNA
# 4                                                         MODERNA
# ...                                                  ...      ...
# 34625                                                     MODERNA
# 34626                                                      PFIZER
# 34627                                                      PFIZER
# 34628                                                     MODERNA
# 34629                                                     MODERNA
#
#                                                 SYMPTOMS      AGE_CAT
# 0                              [Dysphagia, Epiglottitis]     under_60
# 1                                    [Anxiety, Dyspnoea]      over_60
# 2      [Chest discomfort, Dysphagia, Pain in extremit...     under_60
# 3               [Dizziness, Fatigue, Mobility decreased]     under_60
# 4      [Injection site erythema, Injection site pruri...     under_60
# ...                                                  ...          ...
# 34625                   [Dysphagia, Hernia, Obstruction]      over_60
# 34626  [Arrhythmia, Asymptomatic COVID-19, Chills, Co...      over_60
# 34627  [Haemophagocytic lymphohistiocytosis, SARS-CoV...     under_60
# 34628                                            [Death]     under_60
# 34629                                            [Death]  unknown_age
#
# [34121 rows x 9 columns]

# %% [markdown]
# ## Extract the needed columns for training

# %%
df_training = df.loc[:, ['AGE_CAT','SEX','VAX_NAME']]
# combining patients' current illness , medical history and, allergies and store in the "health condition column"
df['HEALTH_CONDITION'] = df['CUR_ILL']+","+ df['HISTORY']+","+df['ALLERGIES']

# %% [markdown]
# ## NLTK PREPROCESSING

# %%
import nltk
import itertools
from string import punctuation
from nltk.corpus import stopwords

punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
stopwords = stopwords.words('english')

# %%
def remove_words_containning_numbers(word):
    if word.isalpha():
        return word
    return ""

# %%
# tokenize df_training['HEALTH_CONDITION']
df['HEALTH_CONDITION']=df['HEALTH_CONDITION'].apply(lambda x : nltk.word_tokenize(x))
allwords=set(itertools.chain.from_iterable(df.HEALTH_CONDITION))
len(allwords)
# Out:
# 16363

# %%
# remove any punctuations from words 
df['HEALTH_CONDITION']=df['HEALTH_CONDITION'].apply(lambda x : [''.join(c for c in s if c not in punctuation) for s in x])
allwords=set(itertools.chain.from_iterable(df.HEALTH_CONDITION))
len(allwords)
# Out:
# 14303

# %%
from textblob import TextBlob
def spell_correct (word):
    return str(TextBlob(word).correct())

# %%
# remove any words mix with number
df['HEALTH_CONDITION']=df['HEALTH_CONDITION'].apply(lambda x : [remove_words_containning_numbers(w) for w in x])
allwords=set(itertools.chain.from_iterable(df.HEALTH_CONDITION))
len(allwords)
# Out:
# 11968

# %%
# remove any empty words
df['HEALTH_CONDITION']=df['HEALTH_CONDITION'].apply(lambda x : [string for string in x if string != ""])
allwords=set(itertools.chain.from_iterable(df.HEALTH_CONDITION))
len(allwords)
# Out:
# 11967

# %%
# remove stop words
df['HEALTH_CONDITION']=df['HEALTH_CONDITION'].apply(lambda x: [words for words in x if words not in stopwords])
allwords=set(itertools.chain.from_iterable(df.HEALTH_CONDITION))
len(allwords)
# Out:
# 11836

# %% [markdown]
# ## auto correct spelling errors (run paralle), since it takes a long time to run, I saved the data processed dataframe
# import multiprocessing
# from autocorrect import Speller
# import time
# spell = Speller(lang='en')
#
#
# import mypack.correc as co
# import numpy as np
# new_dff=df.loc[0:200,'HEALTH_CONDITION']
# new_dff
# start_time = time.time()
# pool = multiprocessing.Pool()
#
# new_dff=new_dff.apply(lambda x :  pool.map(co.correction, x ))
#
# print("--- %s seconds ---" % (time.time() - start_time))

# %%
new_df=pd.read_csv('savedf4-7.csv', sep=',')
new_df.head(60)
# Out:
#     VAERS_ID  AGE_YRS SEX                                            CUR_ILL  \
# 0     916600    33.00   F                                                NaN
# 1     916601    73.00   F  patient residing at nursing facility. see pati...
# 2     916602    23.00   F                                                NaN
# 3     916603    58.00   F                                   kidney infection
# 4     916604    47.00   F                                                NaN
# 5     916606    44.00   F                                                NaN
# 6     916607    50.00   M                                                NaN
# 7     916608    33.00   M                                                NaN
# 8     916609    71.00   F                                                NaN
# 9     916610    18.00   F                                                NaN
# 10    916611    33.00   F  covid-19 (symptom onset 12-16-20 negative test...
# 11    916613    40.00   F                                                NaN
# 12    916614    29.00   F                                                NaN
# 13    916615    38.00   F                                                NaN
# 14    916617    35.00   F                                                NaN
# 15    916618    24.00   F                                                NaN
# 16    916619    28.00   M                                                NaN
# 17    916620    65.00   M                                                NaN
# 18    916621    25.00   F                                                NaN
# 19    916622    22.00   F                                                NaN
# 20    916623    31.00   F  bacterial upper respiratory infection(2 weeks ...
# 21    916624    27.00   F                                                NaN
# 22    916625    41.00   F                                                NaN
# 23    916626    63.00   F                                                NaN
# 24    916627    49.00   F   constipation, indigestion, not on day of vaccine
# 25    916628    33.00   F                                                NaN
# 26    916629    61.00   M                                                NaN
# 27    916630    56.00   F                                                NaN
# 28    916631    25.00   F                                                NaN
# 29    916632     0.08   M                                                NaN
# 30    916633    57.00   F                                                NaN
# 31    916634    27.00   M                                                NaN
# 32    916635    22.00   F                                                NaN
# 33    916636    49.00   F                                                NaN
# 34    916637    32.00   F                                                NaN
# 35    916638    41.00   M                                                NaN
# 36    916639    46.00   F                                                NaN
# 37    916640    46.00   F                                                NaN
# 38    916642    42.00   F                        covid positive mid november
# 39    916643    28.00   F                                                NaN
# 40    916644    58.00   M                                                NaN
# 41    916645    60.00   F                                                NaN
# 42    916646    37.00   F                                                NaN
# 43    916647    42.00   M                                                NaN
# 44    916648    47.00   F         covid 19, date of symptom onset 11/28/2020
# 45    916649    46.00   F                                                NaN
# 46    916650    28.00   F  was on amoxicillin for tooth abscess (last dos...
# 47    916651    53.00   F                                                NaN
# 48    916652    29.00   F                                                NaN
# 49    916653    49.00   F                                                NaN
# 50    916654    38.00   F            sore throat one week prior to vaccition
# 51    916655    47.00   F                                                NaN
# 52    916656    47.00   F                                                NaN
# 53    916657    33.00   F                                                NaN
# 54    916658    66.00   F                                                NaN
# 55    916659    49.00   F                                                NaN
# 56    916660    61.00   F                                                NaN
# 57    916661    59.00   F                                                NaN
# 58    916662    57.00   F                                           covid 19
# 59    916663    39.00   F                                                NaN
#
#                                               HISTORY  \
# 0                                                 NaN
# 1   patient residing at nursing facility. see pati...
# 2                                                 NaN
# 3   diverticulitis, mitral valve prolapse, osteoar...
# 4                                                 NaN
# 5                                                 NaN
# 6   high blood pressure, high cholesterol, sleep a...
# 7                                                 NaN
# 8   hashimoto's thyroiditis, hypertension, depression
# 9                                                 NaN
# 10                                    obesity anxiety
# 11                                                NaN
# 12                                                NaN
# 13                                   migraines,  pmdd
# 14                                         depression
# 15                                                NaN
# 16                                                NaN
# 17  covid 19 infection with lingering symptoms to ...
# 18                                                  .
# 19                                       asthma, adhd
# 20                                            anxiety
# 21                                                NaN
# 22                             gerd, seasol allergies
# 23                                                NaN
# 24                                         depression
# 25                                                NaN
# 26                        obesity,  htn, gout,anxiety
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                 no
# 33                                                NaN
# 34                                                NaN
# 35                                         depression
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                   endometriosis, anxiety, epilepsy
# 40  ascending aorta aneurysm, hyperlipidemia, hype...
# 41                                                NaN
# 42                                                 no
# 43                                        diabetes ii
# 44                                             asthma
# 45                                          arthritis
# 46  seasol allergies, acid reflux, migraines, anxi...
# 47                       obesity, high blood pressure
# 48                                                NaN
# 49                          multiple sclerosis asthma
# 50                       low back pain varicose veins
# 51                                                NaN
# 52                      hypertension asthma arthritis
# 53                                       hypertension
# 54  hemochromatosis,  high cystolic blood pressure...
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58  hypertension, mitral valve prolapse, hyperlipi...
# 59  history of interl carotid and vertebral artery...
#
#                                             ALLERGIES VAX_NAME  \
# 0                                   pcn and bee venom  MODERNA
# 1                                             "dairy"  MODERNA
# 2                                           shellfish   PFIZER
# 3   diclofec, novacaine, lidocaine, pickles, tomat...  MODERNA
# 4                                                 NaN  MODERNA
# 5                       iodine (shellfish) has epipen  MODERNA
# 6                                          penicillin  MODERNA
# 7                                                 NaN  MODERNA
# 8   sulfa antibiotics, azithromycin,  adhesive in ...  MODERNA
# 9                                           jackfruit  MODERNA
# 10             dust mites  zoloft  wellbutrin  buspar  MODERNA
# 11                                                NaN  MODERNA
# 12                                                NaN  MODERNA
# 13             sulfa, steri strips, adhesive bandages  MODERNA
# 14                                                NaN   PFIZER
# 15                                                NaN  MODERNA
# 16                                  sulfa; wellbutrin   PFIZER
# 17                                                NaN  MODERNA
# 18                              ceftiaxone (rocephin)  MODERNA
# 19                     seasol/environmental allergies  MODERNA
# 20                                           morphine   PFIZER
# 21                                                NaN  MODERNA
# 22                                 pomegrante, avalox   PFIZER
# 23                                                NaN  MODERNA
# 24       blue star ointment (topical ointment), latex  MODERNA
# 25                                                NaN  MODERNA
# 26                                                pcn  MODERNA
# 27                                                NaN  MODERNA
# 28                                       azithromycin  MODERNA
# 29                                                NaN  JANSSEN
# 30                   shellfish, amoxicillin, percocet  MODERNA
# 31                                         penicillin  MODERNA
# 32                                                NaN  MODERNA
# 33                                                NaN   PFIZER
# 34                             nkda or food allergies  MODERNA
# 35                                                NaN   PFIZER
# 36  latex (angioedema)  cipro (angioedema) erythro...  MODERNA
# 37                                                NaN  MODERNA
# 38                             penicillin vancomyocin  MODERNA
# 39                                       seasol, pets   PFIZER
# 40                                                NaN  MODERNA
# 41                                                NaN  MODERNA
# 42                                                nka  MODERNA
# 43                                                NaN  MODERNA
# 44                                                NaN   PFIZER
# 45  morphine mild allergies to pine, ragweed, cats...  MODERNA
# 46                             bas, pineapple, metals  MODERNA
# 47                               azithromycin, bedryl  MODERNA
# 48                                                NaN   PFIZER
# 49                               copaxone ct contrast   PFIZER
# 50                                          compazine   PFIZER
# 51                                         penicillin   PFIZER
# 52                                                NaN   PFIZER
# 53               erythromycin - behavioral as a child  MODERNA
# 54  lactose intolerant, allergic to codeine, skin ...  MODERNA
# 55                                                NaN  MODERNA
# 56                                         penicillin   PFIZER
# 57                                                NaN  MODERNA
# 58                                 augmentin, statins  MODERNA
# 59                                                NaN  MODERNA
#
#                                              SYMPTOMS   AGE_CAT  \
# 0                       ['Dysphagia', 'Epiglottitis']  under_60
# 1                             ['Anxiety', 'Dyspnoea']   over_60
# 2   ['Chest discomfort', 'Dysphagia', 'Pain in ext...  under_60
# 3      ['Dizziness', 'Fatigue', 'Mobility decreased']  under_60
# 4   ['Injection site erythema', 'Injection site pr...  under_60
# 5                             ['Pharyngeal swelling']  under_60
# 6      ['Abdominal pain', 'Chills', 'Sleep disorder']  under_60
# 7                   ['Diarrhoea', 'Nasal congestion']  under_60
# 8   ['Vaccination site erythema', 'Vaccination sit...   over_60
# 9                               ['Rash', 'Urticaria']  under_60
# 10  ['Blood pressure decreased', 'Chest pain', 'Ch...  under_60
# 11  ['Abdominal pain upper', 'Dizziness', 'Dysgeus...  under_60
# 12  ['Blood pressure increased', 'Chest discomfort...  under_60
# 13  ['Injection site erythema', 'Injection site pr...  under_60
# 14  ['Chills', 'Dizziness', 'Injection site pain',...  under_60
# 15                    ['Injection site pain', 'Pain']  under_60
# 16             ['Injection site pain', 'Menorrhagia']  under_60
# 17  ['Arthralgia', 'Chills', 'Headache', 'Mobility...   over_60
# 18       ['Chills', 'Fatigue', 'Headache', 'Myalgia']  under_60
# 19  ['Headache', 'Heart rate increased', 'Injectio...  under_60
# 20                            ['Injection site pain']  under_60
# 21  ['Injection site induration', 'Injection site ...  under_60
# 22  ['Chills', 'Dizziness', 'Nausea', 'Pain', 'Tac...  under_60
# 23                           ['Erythema', 'Pruritus']   over_60
# 24  ['Injection site erythema', 'Injection site in...  under_60
# 25  ['Cough', 'Limb discomfort', 'Pain', 'SARS-CoV...  under_60
# 26      ['Asthenia', 'Chills', 'Headache', 'Myalgia']   over_60
# 27  ['Injection site erythema', 'Injection site pa...  under_60
# 28  ['Chills', 'Feeling cold', 'Feeling hot', 'Mya...  under_60
# 29  ['Abdominal pain upper', 'Abnormal behaviour',...  under_60
# 30  ['Headache', 'Limb discomfort', 'Nasal congest...  under_60
# 31  ['Back pain', 'Cold sweat', 'Headache', 'Nause...  under_60
# 32     ['Injection site swelling', 'Limb discomfort']  under_60
# 33  ['Chills', 'Diarrhoea', 'Fatigue', 'Feeling ab...  under_60
# 34  ['Body temperature increased', 'Chills', 'Fati...  under_60
# 35  ['Hypoaesthesia', 'Pain in extremity', 'Periph...  under_60
# 36                ['Flushing', 'Peripheral swelling']  under_60
# 37  ['Arthralgia', 'Injected limb mobility decreas...  under_60
# 38  ['Chills', 'Headache', 'Nausea', 'Pain', 'Pain...  under_60
# 39  ['Chills', 'Headache', 'Hyperhidrosis', 'Pain'...  under_60
# 40        ['Hypoaesthesia oral', 'Paraesthesia oral']  under_60
# 41  ['Plicated tongue', 'Tongue blistering', 'Tong...  under_60
# 42  ['Chills', 'Dizziness', 'Flank pain', 'Headach...  under_60
# 43  ['Arthralgia', 'Chills', 'General symptom', 'M...  under_60
# 44                  ['Pruritus', 'Rash', 'Urticaria']  under_60
# 45  ['Chills', 'Fatigue', 'Headache', 'Nausea', 'P...  under_60
# 46  ['Headache', 'Heart rate increased', 'Pruritus...  under_60
# 47                              ['Burning sensation']  under_60
# 48  ['Anosmia', 'Chills', 'Diarrhoea', 'Migraine',...  under_60
# 49                          ['Anaphylactic reaction']  under_60
# 50  ['Feeling cold', 'Hypoaesthesia', 'Paraesthesia']  under_60
# 51  ['Chest X-ray normal', 'Computerised tomogram ...  under_60
# 52            ['Arthralgia', 'Back pain', 'Dyspnoea']  under_60
# 53  ['Axillary pain', 'Injection site erythema', '...  under_60
# 54  ['Ear pain', 'Hypoaesthesia', 'Neck pain', 'Ne...   over_60
# 55                      ['Injection site cellulitis']  under_60
# 56  ['Headache', 'Muscle spasms', 'Nausea', 'Pain'...   over_60
# 57                     ['Chills', 'Headache', 'Pain']  under_60
# 58                 ['Myalgia', 'Pyrexia', 'Vomiting']  under_60
# 59  ['Lymphadenopathy', 'Musculoskeletal stiffness...  under_60
#
#                                      HEALTH_CONDITION
# 0                             ['pen', 'bee', 'venom']
# 1   ['patient', 'residing', 'nursing', 'facility',...
# 2                                       ['shellfish']
# 3   ['kidney', 'infection', 'diverticulitis', 'mis...
# 4                                                  []
# 5                     ['iodine', 'shellfish', 'pipe']
# 6   ['high', 'blood', 'pressure', 'high', 'cholest...
# 7                                                  []
# 8   ['hashimoto', 'thyroiditis', 'hypertension', '...
# 9                                       ['jackfruit']
# 10  ['symptom', 'onset', 'negative', 'test', 'day'...
# 11                                                 []
# 12                                                 []
# 13  ['migraine', 'pmid', 'sulla', 'stern', 'strip'...
# 14                                     ['depression']
# 15                                                 []
# 16                            ['sulla', 'wellbutrin']
# 17  ['covid', 'infection', 'lingering', 'symptom',...
# 18                         ['ceftiaxone', 'rocephin']
# 19  ['asthma', 'add', 'seasolenvironmental', 'alle...
# 20  ['bacterial', 'upper', 'respiratory', 'infecti...
# 21                                                 []
# 22  ['ger', 'season', 'allergy', 'pomegrante', 'av...
# 23                                                 []
# 24  ['constitution', 'digestion', 'day', 'vaccine'...
# 25                                                 []
# 26         ['obesity', 'tn', 'out', 'anxiety', 'pen']
# 27                                                 []
# 28                                   ['azithromycin']
# 29                                       ['na', 'na']
# 30           ['shellfish', 'amoxicillin', 'percocet']
# 31                                     ['penicillin']
# 32                                                 []
# 33                                                 []
# 34                         ['nda', 'food', 'allergy']
# 35                                     ['depression']
# 36  ['latex', 'angioedema', 'pro', 'angioedema', '...
# 37                                                 []
# 38  ['covid', 'positive', 'mid', 'november', 'peni...
# 39  ['endometriosis', 'anxiety', 'epilepsy', 'seas...
# 40  ['ascending', 'aorta', 'aneurysm', 'hyperlipid...
# 41                                                 []
# 42                                            ['nka']
# 43                                 ['diabetes', 'ii']
# 44    ['covid', 'date', 'symptom', 'onset', 'asthma']
# 45  ['arthritis', 'morphine', 'mild', 'allergy', '...
# 46  ['amoxicillin', 'tooth', 'abscess', 'last', 'd...
# 47  ['obesity', 'high', 'blood', 'pressure', 'azit...
# 48                                                 []
# 49  ['multiple', 'sclerosis', 'asthma', 'copaxone'...
# 50  ['sore', 'throat', 'one', 'week', 'prior', 'va...
# 51                                     ['penicillin']
# 52            ['hypertension', 'asthma', 'arthritis']
# 53  ['hypertension', 'erythromycin', 'behavioral',...
# 54  ['hemochromatosis', 'high', 'cystic', 'blood',...
# 55                                                 []
# 56                                     ['penicillin']
# 57                                                 []
# 58  ['covid', 'hypertension', 'mistral', 'valve', ...
# 59  ['history', 'inter', 'carotid', 'vertebral', '...

# %%
import ast
new_df['HEALTH_CONDITION']=new_df['HEALTH_CONDITION'].apply(lambda x: ast.literal_eval(x))
new_df['HEALTH_CONDITION']=new_df['HEALTH_CONDITION'].apply(lambda x: [n.strip() for n in x])

# %%
new_df
# Out:
#        VAERS_ID  AGE_YRS SEX  \
# 0        916600     33.0   F
# 1        916601     73.0   F
# 2        916602     23.0   F
# 3        916603     58.0   F
# 4        916604     47.0   F
# ...         ...      ...  ..
# 34116   1113917     88.0   F
# 34117   1113920     83.0   F
# 34118   1113963     59.0   F
# 34119   1115045     57.0   M
# 34120   1115348      NaN   F
#
#                                                  CUR_ILL  \
# 0                                                    NaN
# 1      patient residing at nursing facility. see pati...
# 2                                                    NaN
# 3                                       kidney infection
# 4                                                    NaN
# ...                                                  ...
# 34116                                                NaN
# 34117                                                NaN
# 34118                                                NaN
# 34119                                                NaN
# 34120                                                NaN
#
#                                                  HISTORY  \
# 0                                                    NaN
# 1      patient residing at nursing facility. see pati...
# 2                                                    NaN
# 3      diverticulitis, mitral valve prolapse, osteoar...
# 4                                                    NaN
# ...                                                  ...
# 34116  medical history/concurrent conditions: aortic ...
# 34117  medical history/concurrent conditions: atrial ...
# 34118  medical history/concurrent conditions: type ii...
# 34119  medical history/concurrent conditions: no adve...
# 34120  comments: list of non-encoded patient relevant...
#
#                                                ALLERGIES VAX_NAME  \
# 0                                      pcn and bee venom  MODERNA
# 1                                                "dairy"  MODERNA
# 2                                              shellfish   PFIZER
# 3      diclofec, novacaine, lidocaine, pickles, tomat...  MODERNA
# 4                                                    NaN  MODERNA
# ...                                                  ...      ...
# 34116                                                NaN  MODERNA
# 34117                                                NaN   PFIZER
# 34118                                                NaN   PFIZER
# 34119                                                NaN  MODERNA
# 34120                                                NaN  MODERNA
#
#                                                 SYMPTOMS      AGE_CAT  \
# 0                          ['Dysphagia', 'Epiglottitis']     under_60
# 1                                ['Anxiety', 'Dyspnoea']      over_60
# 2      ['Chest discomfort', 'Dysphagia', 'Pain in ext...     under_60
# 3         ['Dizziness', 'Fatigue', 'Mobility decreased']     under_60
# 4      ['Injection site erythema', 'Injection site pr...     under_60
# ...                                                  ...          ...
# 34116             ['Dysphagia', 'Hernia', 'Obstruction']      over_60
# 34117  ['Arrhythmia', 'Asymptomatic COVID-19', 'Chill...      over_60
# 34118  ['Haemophagocytic lymphohistiocytosis', 'SARS-...     under_60
# 34119                                          ['Death']     under_60
# 34120                                          ['Death']  unknown_age
#
#                                         HEALTH_CONDITION
# 0                                      [pen, bee, venom]
# 1      [patient, residing, nursing, facility, see, pa...
# 2                                            [shellfish]
# 3      [kidney, infection, diverticulitis, mistral, v...
# 4                                                     []
# ...                                                  ...
# 34116  [medical, historyconcurrent, condition, aortic...
# 34117  [medical, historyconcurrent, condition, atrial...
# 34118  [medical, historyconcurrent, condition, type, ...
# 34119  [medical, historyconcurrent, condition, advers...
# 34120  [comment, list, nonencoded, patient, relevant,...
#
# [34121 rows x 10 columns]

# %%
allwords=set(itertools.chain.from_iterable(new_df.HEALTH_CONDITION))
len(allwords)
# Out:
# 9633

# %%
allwords_list=list(allwords)
ans=sorted(allwords_list)
print (ans)
# Out:
# ['aaa', 'aat', 'ab', 'abatacept', 'abd', 'abdomen', 'abdominoperineal', 'ability', 'ablation', 'able', 'abnormal', 'abnormality', 'abnormally', 'abo', 'aboutus', 'above', 'abovemigraines', 'abrasive', 'abrupt', 'abscess', 'abscesshematoma', 'absence', 'absent', 'absolute', 'absolutely', 'absorbing', 'absorption', 'abt', 'abuse', 'ac', 'aca', 'academia', 'academically', 'acalculia', 'acarbose', 'accelerated', 'accept', 'acceptable', 'access', 'accident', 'accompanied', 'accompanying', 'according', 'accordingly', 'ace', 'acetabular', 'acetaminophen', 'acetaminophencodeine', 'acetaminophine', 'acetate', 'acetiminophen', 'acetomephine', 'acetometiphan', 'acetominiphen', 'acetonide', 'acetyl', 'acf', 'ach', 'achalasia', 'achelasia', 'acheswell', 'achieved', 'achieves', 'achrocidin', 'acid', 'acidity', 'acidosis', 'acitretin', 'acknowledged', 'acne', 'acquired', 'acre', 'acromioclavicular', 'across', 'acrylic', 'act', 'acted', 'actemraprednisone', 'actenol', 'acting', 'activated', 'activation', 'active', 'actively', 'activity', 'actonel', 'actor', 'actually', 'acuminata', 'acute', 'acuteonchronic', 'acuterecent', 'acyclovir', 'ada', 'adalimumab', 'add', 'addadhd', 'added', 'adderall', 'addiction', 'addition', 'additive', 'adds', 'adductor', 'adenocarcinoma', 'adenoidectomy', 'adenoma', 'adenomatous', 'adenomyosis', 'adenosine', 'adequate', 'adh', 'adhdadd', 'adhesion', 'adhesive', 'adhesivecontact', 'adjust', 'adjustable', 'adjusted', 'adjustment', 'adjutant', 'adl', 'adm', 'admin', 'administered', 'administration', 'administrative', 'admission', 'admit', 'admits', 'admitted', 'admitting', 'adn', 'adneomyosis', 'adrenergic', 'adrenocortical', 'adrenocot', 'adriamyncin', 'adult', 'adultneeds', 'advance', 'advanced', 'advancing', 'adverse', 'advised', 'ae', 'aeroallergens', 'aerophagia', 'aerosol', 'aether', 'af', 'afebrile', 'affair', 'affect', 'affected', 'affecting', 'affective', 'afi', 'afibflutter', 'afibrvr', 'afibtachycardia', 'afibyear', 'afluria', 'aforementioned', 'afraid', 'africa', 'africanamerican', 'after', 'afternoon', 'afterward', 'afterwards', 'agar', 'age', 'aged', 'agency', 'agenda', 'agent', 'agglutinin', 'aggravated', 'aggregated', 'aggregation', 'aggrenox', 'aggression', 'aggressive', 'agitation', 'ago', 'agocardiac', 'agonist', 'agoraphobia', 'agostarted', 'agranulocytosis', 'agreed', 'agreement', 'ahd', 'ahead', 'aid', 'aide', 'aimevig', 'air', 'airbase', 'airborne', 'airline', 'airspace', 'airway', 'ak', 'aka', 'aki', 'al', 'alan', 'alatrofloxacin', 'alberto', 'album', 'albuminuria', 'albuteral', 'albuterol', 'alcohol', 'alcoholgeneral', 'alcoholic', 'alcoholism', 'alcyclovir', 'aldactone', 'aldehyde', 'alder', 'alendrote', 'alergyasthma', 'alert', 'alex', 'alexa', 'alf', 'algerie', 'algesics', 'alheimers', 'ali', 'alias', 'align', 'alignment', 'alison', 'alive', 'alk', 'alka', 'alkaline', 'alkylamine', 'all', 'alla', 'alleged', 'allegedly', 'alleges', 'allele', 'allergenreactant', 'allergic', 'allergies', 'allergiesadverse', 'allergiesanimal', 'allergiesasthma', 'allergiesatropine', 'allergiescongestion', 'allergiesenvironmental', 'allergieshay', 'allergiesmold', 'allergiesreactions', 'allergiesseasol', 'allergiessinuses', 'allergy', 'allergyadhesive', 'allergydiagnosed', 'allergyfood', 'allergyinduced', 'allergyintolerance', 'allergymild', 'allergyraw', 'allergyseasol', 'allergysensitivity', 'allergysportsinduced', 'allies', 'allmovie', 'allogeneic', 'allopurinol', 'allow', 'allowed', 'allows', 'allspice', 'allusion', 'alma', 'almond', 'almondsaphylaxis', 'almondstree', 'almost', 'alone', 'along', 'alopecia', 'alopurinol', 'alot', 'alpha', 'alphagal', 'alphagan', 'alprazolam', 'already', 'also', 'alt', 'alteplase', 'alteplaseangioedema', 'alteration', 'altered', 'although', 'altitude', 'aluminium', 'aluminum', 'aluminummagnesium', 'alveolar', 'always', 'alxheimer', 'alzehimer', 'alzheimer', 'alzheimers', 'alzheimersdementia', 'am', 'amanda', 'amantadine', 'amatriptoline', 'amauxacillin', 'amber', 'ambient',  ...

# %%
def get_wordnet_pos(tag):
    x, y=tag[0]
    if y.startswith('J'):
        return wordnet.ADJ
    elif y.startswith('V'):
        return wordnet.VERB
    elif y.startswith('N'):
        return wordnet.NOUN
    elif y.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from nltk.corpus import wordnet
from nltk import pos_tag
st =PorterStemmer()
wnl = WordNetLemmatizer()
nltk.tag.pos_tag(['location'])
# Out:
# [('location', 'NN')]

# %%
new_df['HEALTH_CONDITION']=new_df['HEALTH_CONDITION'].apply(lambda x: [wnl.lemmatize(w, pos=get_wordnet_pos(pos_tag([w]))) for w in x ])



#allwords=set(itertools.chain.from_iterable(new_df.HEALTH_CONDITION))
#len(allwords)

# %% [markdown]
# from textblob import Word
# # Lemmatize a word
# def lamma(x):
#     w = Word(x)
#     return w.lemmatize()
#
# lamma("walked")

# %% [markdown]
# from textblob import TextBlob, Word
# # Lemmatize a word
# w = Word('ducks')
# w.lemmatize()
# new_df['HEALTH_CONDITION']=new_df['HEALTH_CONDITION'].apply(lambda x: [lamma(w) for w in x ])

# %%
allwords=set(itertools.chain.from_iterable(new_df.HEALTH_CONDITION))
len(allwords)
# Out:
# 9084

# %%
allwords_list=list(allwords)
ans=sorted(allwords_list)
print (ans)
# Out:
# ['aaa', 'aat', 'ab', 'abatacept', 'abd', 'abdomen', 'abdominoperineal', 'ability', 'ablation', 'able', 'abnormal', 'abnormality', 'abnormally', 'abo', 'aboutus', 'above', 'abovemigraines', 'abrasive', 'abrupt', 'abscess', 'abscesshematoma', 'absence', 'absent', 'absolute', 'absolutely', 'absorb', 'absorption', 'abt', 'abuse', 'ac', 'aca', 'academia', 'academically', 'acalculia', 'acarbose', 'accelerate', 'accept', 'acceptable', 'access', 'accident', 'accompany', 'accord', 'accordingly', 'ace', 'acetabular', 'acetaminophen', 'acetaminophencodeine', 'acetaminophine', 'acetate', 'acetiminophen', 'acetomephine', 'acetometiphan', 'acetominiphen', 'acetonide', 'acetyl', 'acf', 'ach', 'achalasia', 'achelasia', 'acheswell', 'achieve', 'achieves', 'achrocidin', 'acid', 'acidity', 'acidosis', 'acitretin', 'acknowledge', 'acne', 'acquire', 'acre', 'acromioclavicular', 'across', 'acrylic', 'act', 'actemraprednisone', 'actenol', 'activate', 'activation', 'active', 'actively', 'activity', 'actonel', 'actor', 'actually', 'acuminata', 'acute', 'acuteonchronic', 'acuterecent', 'acyclovir', 'ada', 'adalimumab', 'add', 'addadhd', 'adderall', 'addiction', 'addition', 'additive', 'adductor', 'adenocarcinoma', 'adenoidectomy', 'adenoma', 'adenomatous', 'adenomyosis', 'adenosine', 'adequate', 'adh', 'adhdadd', 'adhesion', 'adhesive', 'adhesivecontact', 'adjust', 'adjustable', 'adjustment', 'adjutant', 'adl', 'adm', 'admin', 'administer', 'administration', 'administrative', 'admission', 'admit', 'admits', 'adn', 'adneomyosis', 'adrenergic', 'adrenocortical', 'adrenocot', 'adriamyncin', 'adult', 'adultneeds', 'advance', 'advanced', 'adverse', 'advise', 'ae', 'aeroallergens', 'aerophagia', 'aerosol', 'aether', 'af', 'afebrile', 'affair', 'affect', 'affected', 'affective', 'afi', 'afibflutter', 'afibrvr', 'afibtachycardia', 'afibyear', 'afluria', 'aforementioned', 'afraid', 'africa', 'africanamerican', 'after', 'afternoon', 'afterward', 'afterwards', 'agar', 'age', 'agency', 'agenda', 'agent', 'agglutinin', 'aggravate', 'aggregate', 'aggregation', 'aggrenox', 'aggression', 'aggressive', 'agitation', 'ago', 'agocardiac', 'agonist', 'agoraphobia', 'agostarted', 'agranulocytosis', 'agree', 'agreement', 'ahd', 'ahead', 'aid', 'aide', 'aimevig', 'air', 'airbase', 'airborne', 'airline', 'airspace', 'airway', 'ak', 'aka', 'aki', 'al', 'alan', 'alatrofloxacin', 'alberto', 'album', 'albuminuria', 'albuteral', 'albuterol', 'alcohol', 'alcoholgeneral', 'alcoholic', 'alcoholism', 'alcyclovir', 'aldactone', 'aldehyde', 'alder', 'alendrote', 'alergyasthma', 'alert', 'alex', 'alexa', 'alf', 'algerie', 'algesics', 'alheimers', 'ali', 'alias', 'align', 'alignment', 'alison', 'alive', 'alk', 'alka', 'alkaline', 'alkylamine', 'all', 'alla', 'allege', 'allegedly', 'alleges', 'allele', 'allergenreactant', 'allergic', 'allergiesadverse', 'allergiesanimal', 'allergiesasthma', 'allergiesatropine', 'allergiescongestion', 'allergiesenvironmental', 'allergieshay', 'allergiesmold', 'allergiesreactions', 'allergiesseasol', 'allergiessinuses', 'allergy', 'allergyadhesive', 'allergydiagnosed', 'allergyfood', 'allergyinduced', 'allergyintolerance', 'allergymild', 'allergyraw', 'allergyseasol', 'allergysensitivity', 'allergysportsinduced', 'allmovie', 'allogeneic', 'allopurinol', 'allow', 'allows', 'allspice', 'allusion', 'ally', 'alma', 'almond', 'almondsaphylaxis', 'almondstree', 'almost', 'alone', 'along', 'alopecia', 'alopurinol', 'alot', 'alpha', 'alphagal', 'alphagan', 'alprazolam', 'already', 'also', 'alt', 'alteplase', 'alteplaseangioedema', 'alter', 'alteration', 'although', 'altitude', 'aluminium', 'aluminum', 'aluminummagnesium', 'alveolar', 'always', 'alxheimer', 'alzehimer', 'alzheimer', 'alzheimers', 'alzheimersdementia', 'amanda', 'amantadine', 'amatriptoline', 'amauxacillin', 'amber', 'ambient', 'ambienvisual', 'amblyopia', 'ambulance', 'ambulatory', 'amd', 'amenorrhea', 'ami', 'amid', 'amide', 'amino', 'aminoglycosides', 'aminooglycosides', 'amiodarone', 'amiodaroneind ...

# %%
simmilar_word= {'amox':'amoxicillin', 'admin':'admin' ,'acet':'acetaminophen','allerg':'allergy','ampic':"ampicilina",'asthma':'asthma',
               'ather':'Atherosclerosis','ator':'atorvastatin'}

# %%
remove_word_list = ['none', 'na','aaa', 'aat', 'ab','abd','acf', 'ach','after','ak', 'aka', 'aki', 'al', 'alan','alert', 'alex', 'alexa', 'alf','although',
                  'already', 'also', 'b', 'ba', ]

# %%
from nltk.stem.lancaster import LancasterStemmer
st = LancasterStemmer()

new_df['HEALTH_CONDITION']=new_df['HEALTH_CONDITION'].apply(lambda x: [st.stem(w) for w in x ])

# %%
allwords=set(itertools.chain.from_iterable(new_df.HEALTH_CONDITION))
print(len(allwords))
allwords_list=list(allwords)
ans=sorted(allwords_list)
print (ans)
# Out:
# 7762
# ['aa', 'aat', 'ab', 'abataceiv', 'abd', 'abdom', 'abdominoperin', 'abl', 'abnorm', 'abo', 'about', 'abov', 'abovemigrain', 'abras', 'abrupt', 'abs', 'abscess', 'abscesshematom', 'absolv', 'absorb', 'abt', 'abus', 'ac', 'academ', 'acalcul', 'acarbos', 'acceiv', 'accel', 'access', 'accid', 'accompany', 'accord', 'acet', 'acetabul', 'acetaminoph', 'acetaminophencodein', 'acetaminophin', 'acetiminoph', 'acetomephin', 'acetometiph', 'acetominiph', 'acetonid', 'acetyl', 'acf', 'ach', 'achalas', 'achelas', 'acheswel', 'achiev', 'achrocidin', 'acid', 'acidos', 'acitretin', 'acknowledg', 'acn', 'acquir', 'acr', 'acromioclavicul', 'across', 'acryl', 'act', 'actemraprednison', 'actenol', 'actonel', 'acuminat', 'acut', 'acuteonchron', 'acuterec', 'acyclovir', 'ad', 'adalimumab', 'addadhd', 'adderal', 'addict', 'addit', 'adduc', 'adenocarcinom', 'adenoidectom', 'adenom', 'adenomyos', 'adenosin', 'adequ', 'adh', 'adhdad', 'adher', 'adhesivecontact', 'adjust', 'adjut', 'adl', 'adm', 'admin', 'admit', 'adn', 'adneomyos', 'adrenerg', 'adrenocort', 'adrenocot', 'adriamyncin', 'adult', 'adultnee', 'adv', 'advers', 'ae', 'aeroallerg', 'aerophag', 'aerosol', 'aeth', 'af', 'afebril', 'affair', 'affect', 'afibflut', 'afibrvr', 'afibtachycard', 'afibyear', 'aflur', 'afraid', 'afric', 'africanam', 'aft', 'afternoon', 'afterward', 'ag', 'agend', 'agglutinin', 'aggrav', 'aggreg', 'aggrenox', 'aggress', 'agit', 'ago', 'agocardiac', 'agon', 'agoraphob', 'agostart', 'agr', 'agranulocytos', 'agree', 'ahd', 'ahead', 'aid', 'aimevig', 'air', 'airbas', 'airborn', 'airlin', 'airspac', 'airway', 'ak', 'al', 'alatrofloxacin', 'alb', 'alberto', 'albuminur', 'albut', 'albuterol', 'alcohol', 'alcoholg', 'alcyclovir', 'ald', 'aldacton', 'aldehyd', 'alendrot', 'alergyasthm', 'alert', 'alex', 'alf', 'algery', 'alges', 'alheim', 'alia', 'align', 'alison', 'alk', 'alkalin', 'alkylamin', 'all', 'alleg', 'allel', 'allerg', 'allergenreact', 'allergiesadvers', 'allergiesanim', 'allergiesasthm', 'allergiesatropin', 'allergiescongest', 'allergiesenviron', 'allergieshay', 'allergiesmold', 'allergiesreact', 'allergiesseasol', 'allergiessinus', 'allergy', 'allergyadher', 'allergydiagnos', 'allergyfood', 'allergyinduc', 'allergyintol', 'allergymild', 'allergyraw', 'allergyseasol', 'allergysensit', 'allergysportsinduc', 'allmovy', 'allog', 'allopurinol', 'allow', 'allsp', 'allud', 'alm', 'almond', 'almondsaphylax', 'almondst', 'almost', 'alon', 'along', 'alopec', 'alopurinol', 'alot', 'alph', 'alprazolam', 'already', 'also', 'alt', 'alteplas', 'alteplaseangioedem', 'although', 'altitud', 'alumin', 'aluminummagnes', 'alveol', 'alway', 'alxheim', 'alzehim', 'alzheim', 'alzheimersdement', 'am', 'amand', 'amantadin', 'amatriptolin', 'amauxacillin', 'amb', 'ambienv', 'amblyop', 'amby', 'amd', 'amenorrhe', 'amid', 'amino', 'aminoglycosid', 'aminooglycosid', 'amiodaron', 'amiodaroneinduc', 'amioderon', 'amitiz', 'amitriptylin', 'amitryptalin', 'amitryptilin', 'amitryptiltin', 'aml', 'amlodipin', 'amlodopin', 'ammon', 'amnes', 'amnesty', 'amodpehyln', 'among', 'amount', 'amoxacil', 'amoxacillin', 'amoxapin', 'amoxcecil', 'amoxcillin', 'amoxiccillin', 'amoxicil', 'amoxicilin', 'amoxicilliin', 'amoxicillin', 'amoxicillinclav', 'amoxicillinh', 'amoxicillinpenicillin', 'amoxicillinpot', 'amoxicillinrash', 'amoxicillinreact', 'amoxicliin', 'amoxil', 'amoxilcillin', 'amoxocillin', 'amoxocin', 'amoxycil', 'amoxycillin', 'amp', 'amphotericin', 'ampicil', 'ampicillin', 'ampicillinh', 'ampicillinuse', 'amput', 'amyloidos', 'an', 'analog', 'analys', 'anch', 'and', 'androg', 'andryiamicin', 'anectin', 'anem', 'anesthes', 'anesthesiadid', 'anesthet', 'aneurysm', 'ang', 'angel', 'angeoedem', 'angiodem', 'angiodysplas', 'angioedem', 'angioedemaurticar', 'angiogram', 'angiograph', 'angiomyolipom', 'angiopathy', 'angioplasty', 'angiotensin', 'angiotensinconvert', 'angl', 'angleclos', 'anglo', 'angloidos', 'anic', 'anim', 'animalst', 'animos', 'ankl', 'ankleleg', 'ankylos', 'anl', 'annul', 'anom', 'anoma',  ...

# %%
# Out:
# True

# %%
# Out:
# tensor([1., 2., 3.], device='cuda:0')

# %%
new_dff
# Out:
# 0                                        [pen, bee, venom]
# 1        [patient, residing, nursing, facility, see, pa...
# 2                                              [shellfish]
# 3        [kidney, infection, diverticulitis, mistral, v...
# 4                                                       []
#                                ...
# 34625    [medical, historyconcurrent, condition, aortic...
# 34626    [medical, historyconcurrent, condition, atrial...
# 34627    [medical, historyconcurrent, condition, type, ...
# 34628    [medical, historyconcurrent, condition, advers...
# 34629    [comment, list, nonencoded, patient, relevant,...
# Name: HEALTH_CONDITION, Length: 34121, dtype: object

# %%
df['HEALTH_CONDITION'] = new_dff

# %%
df
# Out:
#        VAERS_ID AGE_YRS SEX  \
# 0        916600    33.0   F
# 1        916601    73.0   F
# 2        916602    23.0   F
# 3        916603    58.0   F
# 4        916604    47.0   F
# ...         ...     ...  ..
# 34625   1113917    88.0   F
# 34626   1113920    83.0   F
# 34627   1113963    59.0   F
# 34628   1115045    57.0   M
# 34629   1115348           F
#
#                                                  CUR_ILL  \
# 0
# 1      patient residing at nursing facility. see pati...
# 2
# 3                                       kidney infection
# 4
# ...                                                  ...
# 34625
# 34626
# 34627
# 34628
# 34629
#
#                                                  HISTORY  \
# 0
# 1      patient residing at nursing facility. see pati...
# 2
# 3      diverticulitis, mitral valve prolapse, osteoar...
# 4
# ...                                                  ...
# 34625  medical history/concurrent conditions: aortic ...
# 34626  medical history/concurrent conditions: atrial ...
# 34627  medical history/concurrent conditions: type ii...
# 34628  medical history/concurrent conditions: no adve...
# 34629  comments: list of non-encoded patient relevant...
#
#                                                ALLERGIES VAX_NAME  \
# 0                                      pcn and bee venom  MODERNA
# 1                                                "dairy"  MODERNA
# 2                                              shellfish   PFIZER
# 3      diclofec, novacaine, lidocaine, pickles, tomat...  MODERNA
# 4                                                         MODERNA
# ...                                                  ...      ...
# 34625                                                     MODERNA
# 34626                                                      PFIZER
# 34627                                                      PFIZER
# 34628                                                     MODERNA
# 34629                                                     MODERNA
#
#                                                 SYMPTOMS      AGE_CAT  \
# 0                              [Dysphagia, Epiglottitis]     under_60
# 1                                    [Anxiety, Dyspnoea]      over_60
# 2      [Chest discomfort, Dysphagia, Pain in extremit...     under_60
# 3               [Dizziness, Fatigue, Mobility decreased]     under_60
# 4      [Injection site erythema, Injection site pruri...     under_60
# ...                                                  ...          ...
# 34625                   [Dysphagia, Hernia, Obstruction]      over_60
# 34626  [Arrhythmia, Asymptomatic COVID-19, Chills, Co...      over_60
# 34627  [Haemophagocytic lymphohistiocytosis, SARS-CoV...     under_60
# 34628                                            [Death]     under_60
# 34629                                            [Death]  unknown_age
#
#                                         HEALTH_CONDITION
# 0                                      [pen, bee, venom]
# 1      [patient, residing, nursing, facility, see, pa...
# 2                                            [shellfish]
# 3      [kidney, infection, diverticulitis, mistral, v...
# 4                                                     []
# ...                                                  ...
# 34625  [medical, historyconcurrent, condition, aortic...
# 34626  [medical, historyconcurrent, condition, atrial...
# 34627  [medical, historyconcurrent, condition, type, ...
# 34628  [medical, historyconcurrent, condition, advers...
# 34629  [comment, list, nonencoded, patient, relevant,...
#
# [34121 rows x 10 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction import text
# define stop words 
addition_stopwords= ['none','None','na','nkda','00', '000', '000mg', '001d', '002d', '008s', '00x0', '01', '010', '0107', '010d', '011', '012', '02', '0200', '021', '029', '02jan2021', '02xa', '03', '0350', '03jan2021', '04', '0400', '041d', '0430', '04jan2021', '04nov2020', '05', '053', '06', '06jan2021', '07', '070s', '08', '080d', '080s', '0845', '08jun', '09', '091', '09nov2020', '0p', '10', '100', '1000', '100mg', '101', '102', '103', '104', '106', '10mg', '10th', '10yrs', '11', '110', '111', '112', '113', '115', '116', '119', '11jan2021', '11th', '12', '120', '1200mg', '1201005', '120320', '120ml', '121', '123', '1245', '125', '125mg', '1273', '129', '12dec2020', '12h', '12mm', '12th', '12xa', '12xd', '13', '130', '135', '13645005', '13apr2016', '13jan2021', '13nov2020', '13th', '14', '140', '142', '142d', '143', '14feb2021', '14th', '15', '1500', '1500mg', '152', '155mg', '15mg', '15min', '15pm', '15th', '16', '160cm', '160mg', '161', '16years', '17', '170s', '17feb2021', '17th', '18', '180', '1800', '18jan2021', '18mm', '18th', '19', '191813001', '192020', '193031009', '1940', '1943', '1944', '1950', '1957', '1960', '1960s', '1965', '1969', '1972', '1973', '1974', '1976', '1977', '1980', '1980s', '1983', '1985', '1986', '1987', '1988', '1989', '1990', '1990s', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '19dec2020', '19feb2021', '19jan2021', '19nov2020', '19th', '1a', '1month', '1onth', '1st', '1week', '1wk', '1x', '20', '200', '2000', '2000s', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '200mg', '201', '2010', '2010h', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '202', '2020', '2021', '20210a', '2022', '203', '204', '205', '209', '20lb', '20mg', '20nov2020', '20s', '20th', '21', '210', '212', '215q', '21dec2020', '21st', '22', '220', '222a', '229', '22dec2020', '22ndhad', '22oct2020', '23', '23dec2020', '24', '24dec2020', '24h', '24th', '25', '250', '2510', '25jan2021', '25mg', '26', '267434003', '26th', '27', '272', '274769005', '279039007', '27dec2020', '27th', '28', '285', '286', '28dec2020', '28mg', '28th', '29', '2921', '293', '298', '299', '29iu', '29nov2020', '29th', '2b', '2cm', '2dm', '2l', '2nd', '2ndary', '2o13', '2weeks', '2x', '2yrs', '30', '300', '3019', '302d', '303', '307', '309', '30mg', '30min', '30mm', '30pm', '30th', '30xa', '30xs', '31', '310', '311', '3112', '315', '318', '319', '31dec2020', '31st', '32', '320', '321', '3222', '324', '33', '34', '345', '35', '354', '359', '36', '367399005', '37', '37am', '38', '39', '396275006', '3a', '3b', '3cm', '3kg', '3l', '3mg', '3mm', '3months', '3rd', '3weeks', '3x', '40', '400', '400047006', '401', '40mg', '40s', '41', '412a', '413', '417k', '42', '421326000', '422166005', '423263001', '42xd', '43', '430pm', '433144002', '44', '440', '443', '445d', '448', '45', '45mg', '46', '462', '465', '47', '48', '49', '491', '493', '4g', '4th', '4x', '4years', '50', '500', '500mg', '501d', '507', '50s', '51', '511', '511a', '512', '512a', '515d', '52', '521', '522', '53', '536', '5370000', '53mg', '54404000', '55', '550', '551', '555', '559', '56', '561', '562', '564', '569', '57', '571', '58', '585', '59', '5cm', '5ft', '5g', '5other', '5q', '5th', '5weeks', '5wks', '5x', '5x0s', '5x9d', '5y', '5yrs', '60', '609', '61', '62', '621', '622', '63', '630pm', '64', '640', '641', '65', '650mg', '66', '67', '671', '68', '68yo', '69', '6dec2020', '6g', '6mg', '6th', '6x', '70', '71', '710', '718', '719', '72', '723', '724', '724698009', '73', '73430006', '73438004', '74', '75', '750', '758', '75mg', '76', '77', '78', '780', '79', '791', '79k', '7th', '80', '800', '800mg', '802d', '80s', '81', '810', '811', '812d', '813', '815', '816', '818', '819', '81mg', '82', '82020', '821a', '828', '829', '83', '838', '84', '841', '85', '8517006', '8580', '86', '87', '875', '88', '89', '890', '891', '898', '899', '89xs', '8am', '8cm', '8h', '8th', '90', '901', '909', '90s', '91', '911', '912', '92', '920', '921', '922', '92814006', '929', '93', '94', '95', '951', '95mg', '96', '97', '98', '99', '991', '998', '9chronic', '9in', '9mm', '9th', 'a1', 'a1c', 'a3', 'a41', 'a46', 'age24', 'alpha1', 'alpha1antitrypsin', 'aox3', 'appendectomy1988', 'apr2020', 'b00', 'b12', 'b19', 'b27', 'b35', 'b91', 'b95', 'b95a', 'b96', 'bipolar1', 'bipolar2', 'bnt162b2', 'brca2', 'c18', 'c25', 'c3', 'c4', 'c44', 'c5', 'c50', 'c53', 'c6', 'c61', 'c677t', 'c7', 'c8', 'c82', 'c85', 'c91', 'cabgx3', 'cd4', 'ckd2', 'ckd3', 'ckd4', 'cov2', 'covid10', 'covid19', 'covid_19', 'd05', 'd12', 'd3', 'd46', 'd49', 'd50', 'd51', 'd53', 'd61', 'd63', 'd64', 'd68', 'd69', 'd72', 'dec2017', 'dec2019', 'dec2020', 'dg6', 'diabetes2', 'diagnosis1', 'dissection2016', 'dm1', 'dm11', 'dm2', 'dmt2', 'dose1', 'e00', 'e02', 'e03', 'e04', 'e06', 'e07', 'e08', 'e10', 'e11', 'e26', 'e27', 'e3', 'e43', 'e46', 'e53', 'e55', 'e56', 'e63', 'e66', 'e73', 'e78', 'e86', 'e87', 'e876', 'e88', 'ees400', 'ef15', 'el0140', 'en6203', 'f01', 'f02', 'f03', 'f05', 'f06', 'f10', 'f17', 'f20', 'f22', 'f25', 'f29', 'f31', 'f32', 'f33', 'f34', 'f39', 'f41', 'f43', 'f44', 'f48', 'f51', 'f73', 'f89', 'f90', 'f95', 'f98', 'feb2020', 'for2', 'fracture11', 'ft4', 'g2', 'g20', 'g25', 'g30', 'g31', 'g35', 'g3a', 'g40', 'g43', 'g44', 'g45', 'g47', 'g56', 'g60', 'g62', 'g6pd', 'g80', 'g81', 'g82', 'g89', 'g93', 'g95', 'h04', 'h1', 'h16', 'h1c', 'h1n1', 'h25', 'h26', 'h35', 'h40', 'h47', 'h52', 'h53', 'h5n1', 'h61', 'h91', 'hba1c', 'her2', 'hga1c', 'hgba1c', 'hsv1', 'hsv2', 'hypertensionr26', 'i05', 'i07', 'i10', 'i11', 'i13', 'i16', 'i21', 'i25', 'i26', 'i27', 'i42', 'i44', 'i45', 'i47', 'i48', 'i49', 'i50', 'i51', 'i63', 'i66', 'i67', 'i69', 'i70', 'i71', 'i72', 'i73', 'i82', 'i83', 'i87', 'i89', 'i95', 'icd10', 'icd9', 'if_covid_prior_vaccination', 'igg4', 'insulin16', 'j01', 'j02', 'j15', 'j18', 'j20', 'j30', 'j31', 'j40', 'j42', 'j43', 'j44', 'j45', 'j69', 'j96', 'j98', 'jak2', 'jan2020', 'jan2021', 'jul2018', 'jul2019', 'jul2020', 'jun2018', 'jun2020', 'k21', 'k29', 'k30', 'k42', 'k43', 'k44', 'k52', 'k55', 'k56', 'k57', 'k58', 'k59', 'k62', 'k63', 'k76', 'k80', 'k85', 'k92', 'known_allergies', 'l02', 'l03', 'l08', 'l1', 'l2', 'l21', 'l23', 'l29', 'l3', 'l30', 'l4', 'l5', 'l53', 'l5s1', 'l5s4', 'l70', 'l80', 'l89', 'l97', 'l98', 'm05', 'm06', 'm10', 'm13', 'm15', 'm17', 'm19', 'm1a', 'm20', 'm24', 'm25', 'm41', 'm43', 'm47', 'm48', 'm51', 'm53', 'm54', 'm62', 'm6us', 'm79', 'm81', 'm85', 'm86', 'mar2020', 'may2020', 'medical_history', 'mm3', 'mso4', 'n0', 'n02', 'n04', 'n147', 'n17', 'n18', 'n20', 'n28', 'n31', 'n32', 'n39', 'n40', 'n62', 'n63', 'n90', 'n92', 'n95', 'nov020', 'nov18', 'nov2019', 'nov2020', 'o2', 'oct2020', 'october2020', 'om1', 'on12', 'on2', 'other_medical_history', 'p2', 'pcv13', 'polyethylene_glycol', 'pt1cn1am0', 'pt2n2am0', 'q21', 'q24', 'q38', 'q44', 'q4hrs', 'q61', 'q66', 'r00', 'r05', 'r06', 'r09', 'r13', 'r14', 'r19', 'r20', 'r23', 'r25', 'r26', 'r27', 'r29', 'r30', 'r31', 'r33', 'r41', 'r42', 'r44', 'r45', 'r47', 'r48', 'r49', 'r50', 'r52', 'r53', 'r54', 'r55', 'r56', 'r60', 'r62', 'r63', 'r73', 'r74', 'r77', 'r78', 'r79', 'r80', 'r93', 'r94', 's06', 's1', 's22', 's28', 's32', 's42', 's60', 's61', 's63', 's70', 's72', 's80', 's81', 's82', 's90', 's91', 'sep2020', 'sm859', 'sm869', 'sp02', 'spo2', 'surgery4', 't1', 't10', 't11', 't12', 't1b2', 't1dm', 't2', 't2dm', 't3', 't3n0', 't4', 't45', 't50', 't7', 't8', 't81', 't9', 'testx2', 'tiax2', 'type1', 'type2', 'type2dm', 'u07', 'v00', 'v15', 'v2', 'w19', 'x1', 'x10', 'x2', 'x20', 'x3', 'x3mo', 'x4', 'x4v', 'x50', 'x5yd', 'x6', 'x7', 'x9', 'y65', 'z11', 'z16', 'z20', 'z23', 'z29', 'z41', 'z43', 'z45', 'z46', 'z48', 'z51', 'z66', 'z68', 'z72', 'z74', 'z79', 'z83', 'z85', 'z86', 'z87', 'z90', 'z91', 'z95', 'z96', 'z97', 'z98', 'z99']
stop_w=text.ENGLISH_STOP_WORDS.union(addition_stopwords)

# %%
MODERNA=df_training[df_training['VAX_NAME']=='MODERNA']
PFIZER=df_training[df_training['VAX_NAME']=='PFIZER']
JANSSEN=df_training[df_training['VAX_NAME']=='JANSSEN']

# %%
MODERNA

# %%
# make df_training data to sparse matrix
tfidf_vectorizer = TfidfVectorizer(stop_words=stop_w)
tfidfs = tfidf_vectorizer.fit_transform(MODERNA['HEALTH_CONDITION'])
tfidfs = pd.DataFrame(tfidfs.toarray(), columns=tfidf_vectorizer.get_feature_names())
dummie_age_sex=pd.get_dummies(MODERNA[['SEX','AGE_CAT']],  prefix='', prefix_sep='').reset_index()
moderna_df=pd.concat([dummie_age_sex,tfidfs], axis=1)

# %%
moderna_df

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=200)
kmeans.fit(moderna_df)

# %%
kmeans.labels_

# %%
MODERNA_CLUSTERED=df[df['VAX_NAME']=='MODERNA'].copy()

MODERNA_CLUSTERED['CLUSTER'] = kmeans.labels_

# %% [markdown]
# ## How many instance are belonging to each cluster

# %%
MODERNA_CLUSTERED.groupby(by='CLUSTER')['VAERS_ID'].agg('count').sort_values()

# %% [markdown]
# ## what are in cluster 90

# %%
sym_freq=MODERNA_CLUSTERED[MODERNA_CLUSTERED['CLUSTER']==90]
sym_freq

# %% [markdown]
# ## Symptoms frequency in cluster 90

# %%
from itertools import chain
from collections import Counter
pd.Series(Counter(chain.from_iterable(sym_freq.SYMPTOMS.dropna()))).sort_values(ascending=False)
